# %%
import pandas as pd
df= pd.read_json("Scraped_data/product_metadata.json")
df.head()
# Out:
#                                        product_1           product_2  \
# id                                             1                   2
# product_name   Wooden motif for decoration strip        Bowl rainbow
# manufacturer                          Manufactum  Fundamental Berlin
# price                                    17,90 €             69,90 €
# variants_info                    + more variants     + more variants
#
#                         product_3     product_4     product_5  \
# id                              3             4             5
# product_name         Bowl rainbow   Apples felt  Felt bouquet
# manufacturer   Fundamental Berlin  Én Gry & Sif  Én Gry & Sif
# price                    149,00 €       12,90 €       84,90 €
# variants_info     + more variants
#
#                                      product_6     product_7      product_8  \
# id                                           6             7              8
# product_name   Small wicker basket with handle     Bees felt  Blue tit felt
# manufacturer                       Weidenprofi  Én Gry & Sif   Én Gry & Sif
# price                                  42,90 €        8,90 €         9,90 €
# variants_info
#
#                         product_9                 product_10  ...  \
# id                              9                         10  ...
# product_name   Cotton branch felt  Willow catkin branch felt  ...
# manufacturer         Én Gry & Sif               Én Gry & Sif  ...
# price                     22,90 €                    37,90 €  ...
# variants_info                                                 ...
#
#                          product_1072            product_1073  \
# id                               1072                    1073
# product_name      Banker light, White     Banker light, Green
# manufacturer   Berliner Messinglampen  Berliner Messinglampen
# price                        399,00 €                399,00 €
# variants_info         + more variants         + more variants
#
#                                             product_1074  \
# id                                                  1074
# product_name   Funiculi table lamp, RAL 9001 Cream white
# manufacturer                                      marset
# price                                           229,00 €
# variants_info                            + more variants
#
#                                           product_1075  \
# id                                                1075
# product_name   Funiculi table lamp, RAL 7003 Moss gray
# manufacturer                                    marset
# price                                         229,00 €
# variants_info                          + more variants
#
#                                            product_1076  \
# id                                                 1076
# product_name   Funiculi table lamp, RAL 9005 Deep black
# manufacturer                                     marset
# price                                          229,00 €
# variants_info                           + more variants
#
#                                            product_1077  \
# id                                                 1077
# product_name   Table lamp w182 Pastille b2, Matte black
# manufacturer                                   wästberg
# price                                          399,00 €
# variants_info
#
#                                  product_1078                   product_1079  \
# id                                       1078                           1079
# product_name   Le Klint table lamp 375, 18 cm  Table lamp Bone China, Nature
# manufacturer                         Le Klint                   Original BTC
# price                                479,00 €                       359,00 €
# variants_info
#
#                                         product_1080  \
# id                                              1080
# product_name   Midgard spring table lamp, With stand
# manufacturer                           Midgard light
# price                                       495,00 €
# variants_info
#
#                                                     product_1081
# id                                                          1081
# product_name   Tonone desk lamp steel and aluminum 2 arms, Wi...
# manufacturer                                              Tonone
# price                                                   499,00 €
# variants_info
#
# [5 rows x 1081 columns]

# %%
df_new = df.T

# %%
df_new.index.name = "product"
df_new.reset_index()
df_new.head(10)
# Out:
#             id                       product_name        manufacturer  \
# product
# product_1    1  Wooden motif for decoration strip          Manufactum
# product_2    2                       Bowl rainbow  Fundamental Berlin
# product_3    3                       Bowl rainbow  Fundamental Berlin
# product_4    4                        Apples felt        Én Gry & Sif
# product_5    5                       Felt bouquet        Én Gry & Sif
# product_6    6    Small wicker basket with handle         Weidenprofi
# product_7    7                          Bees felt        Én Gry & Sif
# product_8    8                      Blue tit felt        Én Gry & Sif
# product_9    9                 Cotton branch felt        Én Gry & Sif
# product_10  10          Willow catkin branch felt        Én Gry & Sif
#
#                price    variants_info  \
# product
# product_1    17,90 €  + more variants
# product_2    69,90 €  + more variants
# product_3   149,00 €  + more variants
# product_4    12,90 €
# product_5    84,90 €
# product_6    42,90 €
# product_7     8,90 €
# product_8     9,90 €
# product_9    22,90 €
# product_10   37,90 €
#
#                                                   product_url  \
# product
# product_1   https://www.manufactum.com/wooden-motif-decora...
# product_2     https://www.manufactum.com/bowl-rainbow-a29011/
# product_3     https://www.manufactum.com/bowl-rainbow-a29012/
# product_4     https://www.manufactum.com/apples-felt-a205123/
# product_5    https://www.manufactum.com/felt-bouquet-a215451/
# product_6   https://www.manufactum.com/small-wicker-basket...
# product_7       https://www.manufactum.com/bees-felt-a212587/
# product_8   https://www.manufactum.com/blue-tit-felt-a210095/
# product_9   https://www.manufactum.com/cotton-branch-felt-...
# product_10  https://www.manufactum.com/willow-catkin-branc...
#
#                       category  \
# product
# product_1   easter_decorations
# product_2   easter_decorations
# product_3   easter_decorations
# product_4   easter_decorations
# product_5   easter_decorations
# product_6   easter_decorations
# product_7   easter_decorations
# product_8   easter_decorations
# product_9   easter_decorations
# product_10  easter_decorations
#
#                                                     image_url  \
# product
# product_1   https://assets.manufactum.de/p/212/212731/2127...
# product_2   https://assets.manufactum.de/assets/img/0001/0...
# product_3   https://assets.manufactum.de/p/029/029012/2901...
# product_4   https://assets.manufactum.de/p/205/205123/2051...
# product_5   https://assets.manufactum.de/assets/img/0014/0...
# product_6   https://assets.manufactum.de/assets/img/0014/0...
# product_7   https://assets.manufactum.de/p/212/212587/2125...
# product_8   https://assets.manufactum.de/p/210/210095/2100...
# product_9   https://assets.manufactum.de/p/207/207573/2075...
# product_10  https://assets.manufactum.de/p/205/205124/2051...
#
#                                      alt_text  \
# product
# product_1   Wooden motif for decoration strip
# product_2                        Bowl rainbow
# product_3                        Bowl rainbow
# product_4                         Apples felt
# product_5                        Felt bouquet
# product_6     Small wicker basket with handle
# product_7                           Bees felt
# product_8                       Blue tit felt
# product_9                  Cotton branch felt
# product_10          Willow catkin branch felt
#
#                                                   description  \
# product
# product_1                                                 NaN
# product_2                                                 NaN
# product_3                                                 NaN
# product_4   General Information\n(Almost) Eternal Temptati...
# product_5   General Information\nA bouquet of colorful fel...
# product_6   General Information\nReliably versatile. Not j...
# product_7   General Information\nBuzz, buzz, buzz, little ...
# product_8   General Information\nFlink, cheeky, cheerful\n...
# product_9   Customers who viewed this item also liked\nFor...
# product_10  General Information\nLong-lasting Easter branc...
#
#                                                    dimensions
# product
# product_1                                                 NaN
# product_2                                                 NaN
# product_3                                                 NaN
# product_4          {'height': '5.5 cm', 'diameter': '3.5 cm'}
# product_5   {'height': '10 cm', 'depth': '44 cm', 'diamete...
# product_6            {'height': '12 cm', 'diameter': '24 cm'}
# product_7   {'height': '5 cm', 'length': '5 cm', 'diameter...
# product_8   {'height': '3.5 cm', 'width': '3.5 cm', 'lengt...
# product_9                                                 NaN
# product_10               {'height': '40 cm', 'width': '1 cm'}

# %% [markdown]
# ## Scrape OTTO products by category
#
# Read the categories from the OTTO sample data and collect up to 10 products per category from OTTO search results.

# %% [markdown]
# ## Stage 1: Unsupervised Retrieval with Cosine Similarity
#
# Build customer profiles from weighted product interactions and retrieve the most similar unseen products from the full catalog.
